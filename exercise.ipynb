# %%
import os 
import pprint
import csv
import pandas as pd
import numpy as np

filename = './human_development.csv'

array_of_stats = pd.read_csv(filename)
array_of_stats


dd = array_of_stats.as_matrix()
# Out:
# array([[1.0, 'Norway', 0.9440000000000001, ..., 12.6, '64,992', 5.0],
#        [2.0, 'Australia', 0.935, ..., 13.0, '42,261', 17.0],
#        [3.0, 'Switzerland', 0.93, ..., 12.8, '56,431', 6.0],
#        ...,
#        [nan, 'South Asia', 0.607, ..., 5.5, '5,605', nan],
#        [nan, 'Sub-Saharan Africa', 0.518, ..., 5.2, '3,363', nan],
#        [nan, 'World', 0.711, ..., 7.9, '14,301', nan]], dtype=object)

# %%
#Which country has the highest HDI (Human Development Index) and which has the lowest?
highest_HDI = np.max(dd[:,2])
print(highest_HDI)
lowest_HDI = np.min(dd[:,2])
print(lowest_HDI)

for d in dd:
    if d[2] == highest_HDI:
        print("{} has the highest Human Development Index".format(d[1]))
    if d[2] == lowest_HDI:
        print("{} has the lowest Human Development Index".format(d[1]))
# Out:
# 0.9440000000000001
# 0.348
# Norway has the highest Human Development Index
# Niger has the lowest Human Development Index

# %%
import ast
#Which country has raised its HDI the most, in the period 1990 to 2014?
filename2 = './historical_index.csv'

array_of_stats = pd.read_csv(filename2)
array_of_stats

growth = []
my_array = []
dd = array_of_stats.as_matrix()
for d in dd:
    if d[2] == '..' or d[3] == '..':
        d2 = 0
        result = d[8] - d2
        growth.append(result)
        my_array.append(d[1])
        my_array.append(result)
    else:
        d2 = ast.literal_eval(d[2])
        result = d[8] - d2
        growth.append(result)
        my_array.append(d[1])
        my_array.append(result)
highest_increase = np.max(growth)
for e in my_array:
    if e == highest_increase:
        country = my_array.index(highest_increase) - 1
        print("{} has increased the most by {}".format(my_array[country], highest_increase))
# Out:
# Liechtenstein has increased the most by 0.9079999999999999

# %%
filename2 = './database.csv'

array_of_stats = pd.read_csv(filename2)
array_of_stats

dd = array_of_stats.as_matrix()
military = []
for d in dd:
    if d[4] == 'Military':
        military.append(d)
military = np.array(military)
countries = np.unique(military[:,3])

#for c in countries:
 #   for m in military:
  #      if m[3] == c:
   #         my_array.append(m)
    #my_size = np.size(my_array)
    #print("{} has {} satelites".format(c, my_size))
# Out:
#                 0        1   \
# 0          USA 139      USA
# 1          USA 171      USA
# 2          USA 202      USA
# 3          USA 223      USA
# 4          USA 237      USA
# 5          USA 268       NR
# 6          USA 235      USA
# 7          USA 246       NR
# 8            ALiCE       NR
# 9      Cosmos 2503   Russia
# 10     Cosmos 2515       NR
# 11     CartoSat 2A    India
# 12         USA 257      USA
# 13      COMSATBw-1  Germany
# 14      COMSATBw-2  Germany
# 15       Condor E2       NR
# 16        Coriolis      USA
# 17     Cosmos 2504       NR
# 18         USA 131      USA
# 19         USA 147      USA
# 20         USA 172      USA
# 21         USA 173      USA
# 22         USA 210      USA
# 23         USA 167      USA
# 24         USA 170      USA
# 25         USA 135      USA
# 26         USA 148      USA
# 27         USA 153      USA
# 28         USA 113      USA
# 29         USA 130      USA
# ..             ...      ...
# 212      Yaogan 12    China
# 213      Yaogan 13    China
# 214      Yaogan 14    China
# 215      Yaogan 15    China
# 216     Yaogan 16A    China
# 217     Yaogan 16B       NR
# 218     Yaogan 16C       NR
# 219     Yaogan 17A    China
# 220     Yaogan 17B       NR
# 221     Yaogan 17C       NR
# 222      Yaogan 18    China
# 223      Yaogan 19    China
# 224     Yaogan 20A       NR
# 225     Yaogan 20C       NR
# 226      Yaogan 21       NR
# 227      Yaogan 22       NR
# 228      Yaogan 23       NR
# 229      Yaogan 24       NR
# 230     Yaogan 25A       NR
# 231     Yaogan 25B       NR
# 232     Yaogan 25C       NR
# 233      Yaogan 26       NR
# 234      Yaogan 27       NR
# 235      Yaogan 28       NR
# 236      Yaogan 29       NR
# 237      Yaogan 30       NR
# 238      Ziyuan 2C    China
# 239   Zhongxing 1A    China
# 240  Zhongxing 20A    China
# 241  Zhongxing 22A    China
#
#                                                     2             3   \
# 0                 National Reconnaissance Office (NRO)           USA
# 1                 National Reconnaissance Office (NRO)           USA
# 2                 National Reconnaissance Office (NRO)           USA
# 3                 National Reconnaissance Office (NRO)           USA
# 4                 National Reconnaissance Office (NRO)           USA
# 5                 National Reconnaissance Office (NRO)           USA
# 6                                         US Air Force           USA
# 7                                         US Air Force           USA
# 8                 US Air Force Institute of Technology           USA
# 9                                  Ministry of Defense        Russia
# 10                                 Ministry of Defense        Russia
# 11           Indian Space Research Organization (ISRO)         India
# 12                                   Unknown US agency           USA
# 13                                        Armed Forces       Germany
# 14                                        Armed Forces       Germany
# 15                                        Armed Forces  South Africa
# 16                          US Air Force/ US Navy/NASA           USA
# 17                                 Ministry of Defense        Russia
# 18                                            DoD/NOAA           USA
# 19                                            DoD/NOAA           USA
# 20                                            DoD/NOAA           USA
# 21                                            DoD/NOAA           USA
# 22                                            DoD/NOAA           USA
# 23                                        US Air Force           USA
# 24                                        US Air Force           USA
# 25                                        US Air Force           USA
# 26                                        US Air Force           USA
# 27                                        US Air Force           USA
# 28                                        US Air Force           USA
# 29                                           Air Force           USA
# ..                                                 ...           ...
# 212                     People's Liberation Army (C41)         China
# 213                     People's Liberation Army (C41)         China
# 214                     People's Liberation Army (C41)         China
# 215                     People's Liberation Army (C41)         China
# 216                     People's Liberation Army (C41)         China
# 217                     People's Liberation Army (C41)         China
# 218                     People's Liberation Army (C41)         China
# 219                     People's Liberation Army (C41)         China
# 220                     People's Liberation Army (C41)         China
# 221                     People's Liberation Army (C41)         China
# 222                     People's Liberation Army (C41)         China
# 223                     People's Liberation Army (C41)         China
# 224                     People's Liberation Army (C41)         China
# 225                     People's Liberation Army (C41)         China
# 226                     People's Liberation Army (C41)         China
# 227                     People's Liberation Army (C41)         China
# 228                     People's Liberation Army (C41)         China
# 229                     People's Liberation Army (C41)         China
# 230                     People's Liberation Army (C41)         China
# 231                     People's Liberation Army (C41)         China
# 232                     People's Liberation Army (C41)         China
# 233                     People's Liberation Army (C41)         China
# 234                     People's Liberation Army (C41)         China
# 235                     People's Liberation Army (C41)         China
# 236                     People's Liberation Army (C41)         China
# 237                     People's Liberation Army (C41)         China
# 238                Chinese Academy of Space Technology         China
# 239                     People's Liberation Army (C41)         China
# 240                     People's Liberation Army (C41)         China
# 241  China Satellite Communication Corp. (China Sat...         China
#
#            4                       5                         6    7   \
# 0    Military       Earth Observation   Electronic Intelligence  GEO
# 1    Military       Earth Observation   Electronic Intelligence  GEO
# 2    Military       Earth Observation   Electronic Intelligence  GEO
# 3    Military       Earth Observation   Electronic Intelligence  GEO
# 4    Military       Earth Observation   Electronic Intelligence  GEO
# 5    Military       Earth Observation   Electronic Intelligence  GEO
# 6    Military          Communications                       NaN  GEO
# 7    Military          Communications                       NaN  GEO
# 8    Military  Technology Development                       NaN  LEO
# 9    Military       Earth Observation   Electronic Intelligence  LEO
# 10   Military       Earth Observation   Electronic Intelligence  LEO
# 11   Military       Earth Observation           Optical Imaging  LEO
# 12   Military          Communications                       NaN  GEO
# 13   Military          Communications                       NaN  GEO
# 14   Military          Communications                       NaN  GEO
# 15   Military       Earth Observation             Radar Imaging  LEO
# 16   Military     Earth/Space Science                       NaN  LEO
# 17   Military  Technology Development                       NaN  LEO
# 18   Military       Earth Observation  Earth Science/Meterology  LEO
# 19   Military       Earth Observation  Earth Science/Meterology  LEO
# 20   Military       Earth Observation  Earth Science/Meterology  LEO
# 21   Military       Earth Observation  Earth Science/Meterology  LEO
# 22   Military       Earth Observation  Earth Science/Meterology  LEO
# 23   Military          Communications                       NaN  GEO
# 24   Military          Communications                       NaN  GEO
# 25   Military          Communications                       NaN  GEO
# 26   Military          Communications                       NaN  GEO
# 27   Military          Communications                       NaN  GEO
# 28   Military          Communications                       NaN  GEO
# 29   Military       Earth Observation          Infrared Imaging  GEO
# ..        ...                     ...                       ...  ...
# 212  Military       Earth Observation                       NaN  LEO
# 213  Military       Earth Observation                       NaN  LEO
# 214  Military       Earth Observation                       NaN  LEO
# 215  Military       Earth Observation                       NaN  LEO
# 216  Military       Earth Observation   Electronic Intelligence  LEO
# 217  Military       Earth Observation   Electronic Intelligence  LEO
# 218  Military       Earth Observation   Electronic Intelligence  LEO
# 219  Military       Earth Observation   Electronic Intelligence  LEO
# 220  Military       Earth Observation   Electronic Intelligence  LEO
# 221  Military       Earth Observation   Electronic Intelligence  LEO
# 222  Military       Earth Observation                       NaN  LEO
# 223  Military       Earth Observation                       NaN  LEO
# 224  Military       Earth Observation   Electronic Intelligence  LEO
# 225  Military       Earth Observation   Electronic Intelligence  LEO
# 226  Military       Earth Observation                       NaN  LEO
# 227  Military       Earth Observation                       NaN  LEO
# 228  Military       Earth Observation                       NaN  LEO
# 229  Military       Earth Observation                       NaN  LEO
# 230  Military       Earth Observation   Electronic Intelligence  LEO
# 231  Military       Earth Observation   Electronic Intelligence  LEO
# 232  Military       Earth Observation   Electronic Intelligence  LEO
# 233  Military       Earth Observation                       NaN  LEO
# 234  Military       Earth Observation           Optical Imaging  LEO
# 235  Military       Earth Observation           Optical Imaging  LEO
# 236  Military       Earth Observation             Radar Imaging  LEO
# 237  Military       Earth Observation                       NaN  LEO
# 238  Military       Earth Observation           Optical Imaging  LEO
# 239  Military          Communications                       NaN  GEO
# 240  Military          Communications                       NaN  GEO
# 241  Military          Communications                       NaN  GEO
#
#                      8       9   ...     16    17          18   19  \
# 0                   NaN   -14.5  ...    NaN   NaN    5/9/1998  NaN
# 1                   NaN    95.4  ...    NaN   NaN    9/9/2003  NaN
# 2                   NaN      44  ...    NaN   NaN   1/18/2009  NaN
# 3                   NaN   100.9  ...    NaN   NaN  11/21/2010  NaN
# 4                   NaN      60  ...    NaN   NaN   6/29/2012  NaN
# 5                   NaN     103  ...    NaN   NaN   6/11/2016  NaN
# 6                   NaN    -120  ...    NaN   NaN    5/3/2012   14
# 7                   NaN     NaN  ...    NaN   NaN   9/18/2013   14
# 8                 Polar       0  ...    NaN   NaN   12/6/2013  NaN
# 9       Sun-Synchronous       0  ...    NaN   NaN   2/27/2015    5
# 10      Sun-Synchronous       0  ...    NaN   NaN   3/24/2016    5
# 11      Sun-Synchronous       0  ...    NaN   NaN   4/28/2008    5
# 12                  NaN     106  ...    NaN   NaN   9/16/2014  NaN
# 13                  NaN      63  ...    NaN  3500   10/1/2009   15
# 14                  NaN    13.2  ...    NaN  3500   5/21/2010   15
# 15                Polar       0  ...    NaN   NaN  12/19/2014  NaN
# 16      Sun-Synchronous       0  ...    395  1174    1/6/2003    3
# 17                Polar       0  ...    NaN   NaN   3/31/2015  NaN
# 18      Sun-Synchronous       0  ...    823   900    4/4/1997    5
# 19      Sun-Synchronous       0  ...    823   900  12/12/1999    5
# 20      Sun-Synchronous       0  ...    825   900  10/18/2003    5
# 21      Sun-Synchronous       0  ...    825   900   11/4/2006    5
# 22      Sun-Synchronous       0  ...    825   900  10/18/2009    5
# 23                  NaN   60.01  ...    884  1240   3/11/2003   10
# 24                  NaN  -52.51  ...    884  1240   8/29/2003   10
# 25                  NaN -130.05  ...    884  1240  10/24/1997   10
# 26                  NaN -135.11  ...    884  1240    1/1/2000   10
# 27                  NaN  -12.15  ...    884  1240  10/20/2000   10
# 28                  NaN   -52.4  ...    884  1240   7/31/1995   10
# 29                  NaN       0  ...    NaN  1485   2/23/1997    5
# ..                  ...     ...  ...    ...   ...         ...  ...
# 212     Sun-Synchronous       0  ...    NaN   NaN   11/9/2011  NaN
# 213     Sun-Synchronous       0  ...    NaN   NaN  11/29/2011  NaN
# 214     Sun-Synchronous       0  ...    NaN   NaN   5/10/2012  NaN
# 215               Polar       0  ...    NaN   NaN   5/29/2012  NaN
# 216  Non-Polar Inclined       0  ...    NaN   NaN  11/25/2012  NaN
# 217  Non-Polar Inclined       0  ...    NaN   NaN  11/25/2012  NaN
# 218  Non-Polar Inclined       0  ...    NaN   NaN  11/25/2012  NaN
# 219  Non-Polar Inclined       0  ...    NaN   NaN    9/1/2013  NaN
# 220  Non-Polar Inclined       0  ...    NaN   NaN    9/1/2013  NaN
# 221  Non-Polar Inclined       0  ...    NaN   NaN    9/1/2013  NaN
# 222     Sun-Synchronous       0  ...    NaN   NaN  10/29/2013  NaN
# 223     Sun-Synchronous       0  ...    NaN   NaN  11/20/2013  NaN
# 224  Non-Polar Inclined       0  ...    NaN   NaN    8/9/2014  NaN
# 225  Non-Polar Inclined       0  ...    NaN   NaN    8/9/2014  NaN
# 226     Sun-Synchronous       0  ...    NaN   NaN    9/8/2014  NaN
# 227     Sun-Synchronous       0  ...    NaN   NaN  10/20/2014  NaN
# 228     Sun-Synchronous       0  ...    NaN   NaN  11/14/2014  NaN
# 229     Sun-Synchronous       0  ...    NaN   NaN  11/20/2014  NaN
# 230  Non-Polar Inclined       0  ...    NaN   NaN  12/10/2014  NaN
# 231  Non-Polar Inclined       0  ...    NaN   NaN  12/10/2014  NaN
# 232  Non-Polar Inclined       0  ...    NaN   NaN  12/10/2014  NaN
# 233     Sun-Synchronous       0  ...    NaN   NaN  12/27/2014  NaN
# 234     Sun-Synchronous       0  ...    NaN   NaN   8/27/2015  NaN
# 235     Sun-Synchronous       0  ...    NaN   NaN   11/8/2015  NaN
# 236     Sun-Synchronous       0  ...    NaN   NaN  11/26/2015  NaN
# 237     Sun-Synchronous       0  ...    NaN   NaN   5/15/2016  NaN
# 238     Sun-Synchronous       0  ...    NaN   NaN   11/4/2004  3-5
# 239                 NaN  129.84  ...    NaN   NaN   9/18/2011  NaN
# 240                 NaN     130  ...    NaN   NaN  11/24/2010  NaN
# 241                 NaN  103.28  ...    NaN   NaN   9/12/2006  NaN
#
#                                                   20            21  \
# 0                          TRW Space and Electronics           USA
# 1                          TRW Space and Electronics           USA
# 2             National Reconnaissance Laboratory (?)           USA
# 3             National Reconnaissance Laboratory (?)           USA
# 4             National Reconnaissance Laboratory (?)           USA
# 5             National Reconnaissance Laboratory (?)           USA
# 6                      Lockheed Martin Space Systems           USA
# 7                      Lockheed Martin Space Systems           USA
# 8               US Air Force Institute of Technology           USA
# 9                   Progress Rocket and Space Center        Russia
# 10                  Progress Rocket and Space Center        Russia
# 11         Indian Space Research Organization (ISRO)         India
# 12                                   Lockheed Martin           USA
# 13                               Thales Alenia Space  France/Italy
# 14                               Thales Alenia Space  France/Italy
# 15                             NPO Mashinostroyeniya        Russia
# 16                              Spectrum Astro, Inc.           USA
# 17                                         Reshetnev        Russia
# 18                Lockheed Martin Missiles and Space           USA
# 19                Lockheed Martin Missiles and Space           USA
# 20                Lockheed Martin Missiles and Space           USA
# 21                Lockheed Martin Missiles and Space           USA
# 22                Lockheed Martin Missiles and Space           USA
# 23                Lockheed Martin Missiles and Space           USA
# 24                Lockheed Martin Missiles and Space           USA
# 25                Lockheed Martin Missiles and Space           USA
# 26                Lockheed Martin Missiles and Space           USA
# 27                Lockheed Martin Missiles and Space           USA
# 28                Lockheed Martin Missiles and Space           USA
# 29               TRW and Aerojet Electronics Systems           USA
# ..                                               ...           ...
# 212       Chinese Academy of Space Technology (CAST)         China
# 213  Shanghai Academy of Satellite Technology (SAST)         China
# 214       Chinese Academy of Space Technology (CAST)         China
# 215  Shanghai Academy of Satellite Technology (SAST)         China
# 216       Chinese Academy of Space Technology (CAST)         China
# 217       Chinese Academy of Space Technology (CAST)         China
# 218       Chinese Academy of Space Technology (CAST)         China
# 219  Shanghai Academy of Satellite Technology (SAST)         China
# 220  Shanghai Academy of Satellite Technology (SAST)         China
# 221  Shanghai Academy of Satellite Technology (SAST)         China
# 222  Shanghai Academy of Satellite Technology (SAST)         China
# 223  Shanghai Academy of Satellite Technology (SAST)         China
# 224       Chinese Academy of Space Technology (CAST)         China
# 225       Chinese Academy of Space Technology (CAST)         China
# 226       Chinese Academy of Space Technology (CAST)         China
# 227  Shanghai Academy of Satellite Technology (SAST)         China
# 228  Shanghai Academy of Satellite Technology (SAST)         China
# 229       Chinese Academy of Space Technology (CAST)         China
# 230       Chinese Academy of Space Technology (CAST)         China
# 231       Chinese Academy of Space Technology (CAST)         China
# 232       Chinese Academy of Space Technology (CAST)         China
# 233        Chinese Academy of Space Tecnology (CAST)         China
# 234       Chinese Academy of Space Technology (CAST)         China
# 235        CAST/Changchun Light Technology Institute         China
# 236        CAST/Changchun Light Technology Institute         China
# 237       Chinese Academy of Space Technology (CAST)         China
# 238       Chinese Academy of Space Technology (CAST)         China
# 239       Chinese Academy of Space Technology (CAST)         China
# 240       Chinese Academy of Space Technology (CAST)         China
# 241       Chinese Academy of Space Technology (CAST)         China
#
#                                   22              23          24     25
# 0                     Cape Canaveral       Titan IVA   1998-029A  25336
# 1                     Cape Canaveral        Titan IV   2003-041A  27937
# 2                     Cape Canaveral   Delta 4 Heavy   2009-001A  33490
# 3                     Cape Canaveral   Delta 4 Heavy   2010-063A  37232
# 4                     Cape Canaveral   Delta 4 Heavy   2012-034A  38528
# 5                     Cape Canaveral   Delta 4 Heavy   2016-036A  41584
# 6                     Cape Canaveral         Atlas 5   2012-019A  38254
# 7                     Cape Canaveral         Atlas 5   2013-050A  39256
# 8                     Vandenberg AFB         Atlas 5   2013-072F  39467
# 9                Plesetsk Cosmodrome      Soyuz-2.1b   2015-009A  40420
# 10               Plesetsk Cosmodrome      Soyuz 2.1a   2016-020A  41394
# 11        Satish Dhawan Space Center         PSLV C9   2008-021A  32783
# 12                    Cape Canaveral         Atlas 5   2014-055A  40208
# 13               Guiana Space Center        Ariane 5   2009-054B  35943
# 14               Guiana Space Center        Ariane 5   2010-021B  36582
# 15               Baikonur Cosmodrome          Strela   2014-084A  40353
# 16                    Vandenberg AFB         Titan 2   2003-001A  27640
# 17               Plesetsk Cosmodrome           Rokot   2015-020D  40555
# 18                    Vandenberg AFB         Titan 2   1997-012A  24753
# 19                    Vandenberg AFB         Titan 2   1999-067A  25991
# 20                    Vandenberg AFB         Titan 2   2003-048A  28054
# 21                    Vandenberg AFB         Delta 4   2006-050A  29522
# 22                    Vandenberg AFB         Atlas 5   2009-057A  35951
# 23                    Cape Canaveral        Atlas 2A   2003-008A  27691
# 24                    Cape Canaveral         Delta 4   2003-040A  27875
# 25                    Cape Canaveral         Delta 4   1997-065A  25019
# 26                    Cape Canaveral        Atlas 2A   2000-001A  26052
# 27                    Cape Canaveral        Atlas 2A   2000-065A  26575
# 28                    Cape Canaveral        Atlas 2A   1995-038A  23628
# 29                    Cape Canaveral       Titan IVB   1997-008A  24737
# ..                               ...             ...         ...    ...
# 212            Taiyuan Launch Center   Long March 4B   2011-066B  37875
# 213            Taiyuan Launch Center   Long March 2C   2011-072A  37941
# 214            Taiyuan Launch Center   Long March 4B   2012-021A  38257
# 215            Taiyuan Launch Center   Long March 4C   2012-029A  38354
# 216  Jiuquan Satellite Launch Center   Long March 4C   2012-066A  39011
# 217  Jiuquan Satellite Launch Center   Long March 4C   2012-066B  39012
# 218  Jiuquan Satellite Launch Center   Long March 4C   2012-066C  39013
# 219  Jiuquan Satellite Launch Center   Long March 4C   2013-046A  39239
# 220  Jiuquan Satellite Launch Center   Long March 4C   2013-046B  39240
# 221  Jiuquan Satellite Launch Center   Long March 4C   2013-046C  39241
# 222            Taiyuan Launch Center   Long March 2C   2013-059A  39363
# 223            Taiyuan Launch Center   Long March 4C   2013-065A  39410
# 224  Jiuquan Satellite Launch Center   Long March 4C   2014-047A  40109
# 225  Jiuquan Satellite Launch Center   Long March 4C   2014-047C  40111
# 226            Taiyuan Launch Center   Long March 4B   2014-053A  40143
# 227            Taiyuan Launch Center   Long March 4C   2014-063A  40275
# 228            Taiyuan Launch Center   Long March 2C   2014-071A  40305
# 229  Jiuquan Satellite Launch Center   Long March 2C   2014-072A  40310
# 230  Jiuquan Satellite Launch Center   Long March 4C   2014-080A  40338
# 231  Jiuquan Satellite Launch Center   Long March 4C   2014-080B  40339
# 232  Jiuquan Satellite Launch Center   Long March 4C  2014-0808C  40340
# 233            Taiyuan Launch Center   Long March 4B   2014-088A  40362
# 234            Taiyuan Launch Center   Long March 4C   2015-040A  40878
# 235            Taiyuan Launch Center   Long March 4B   2015-064A  41026
# 236            Taiyuan Launch Center   Long March 4C   2015-069A  41038
# 237  Jiuquan Satellite Launch Center   Long March 2D   2016-029A  41473
# 238            Taiyuan Launch Center  Chang Zheng 4B   2004-044A  28470
# 239  Xichang Satellite Launch Center   Long March 3B   2011-047A  37804
# 240  Xichang Satellite Launch Center   Long March 3B   2010-064A  37234
# 241  Xichang Satellite Launch Center   Long March 3A   2006-038A  29398
#
# [242 rows x 26 columns]
